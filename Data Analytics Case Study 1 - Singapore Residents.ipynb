# %% [markdown]
# # A. Data Preparation and Cleaning

# %% [markdown]
# In this notebook we will attempt to work on the sample data analytics problem offered by Abhishek Agarrwal about Singapore Residents Data. Link to his Youtube content for this problem https://www.youtube.com/watch?v=xArNPFG_nq0&t=193s

# %% [markdown]
# ### Essential Libraries
# First and foremost is importing the relevant libraries
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib and Seaborn : Library for Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

#Setting the default display options
pd.options.display.max_rows = 999

# %% [markdown]
# Load in the csv file 'singapore-residents data.csv'

# %%
raw = pd.read_csv('singapore-residents data.csv')
raw
# Out:
#      year                        level_1    value
# 0    1960                Total Residents  1646400
# 1    1960           Total Male Residents   859600
# 2    1960         Total Female Residents   786800
# 3    1960                   Total Malays   232200
# 4    1960              Total Male Malays   121000
# 5    1960            Total Female Malays   111200
# 6    1960                  Total Chinese  1251600
# 7    1960             Total Male Chinese   636000
# 8    1960           Total Female Chinese   615600
# 9    1960                  Total Indians   133200
# 10   1960             Total Male Indians    88000
# 11   1960           Total Female Indians    45200
# 12   1960    Other Ethnic Groups (Total)    29400
# 13   1960    Other Ethnic Groups (Males)    14600
# 14   1960  Other Ethnic Groups (Females)    14800
# 15   1961                Total Residents  1702400
# 16   1961           Total Male Residents   886500
# 17   1961         Total Female Residents   815900
# 18   1961                   Total Malays   242500
# 19   1961              Total Male Malays   125700
# 20   1961            Total Female Malays   116800
# 21   1961                  Total Chinese  1295000
# 22   1961             Total Male Chinese   657600
# 23   1961           Total Female Chinese   637400
# 24   1961                  Total Indians   135700
# 25   1961             Total Male Indians    88800
# 26   1961           Total Female Indians    46900
# 27   1961    Other Ethnic Groups (Total)    29200
# 28   1961    Other Ethnic Groups (Males)    14400
# 29   1961  Other Ethnic Groups (Females)    14800
# 30   1962                Total Residents  1750200
# 31   1962           Total Male Residents   909500
# 32   1962         Total Female Residents   840700
# 33   1962                   Total Malays   250300
# 34   1962              Total Male Malays   129300
# 35   1962            Total Female Malays   121000
# 36   1962                  Total Chinese  1333000
# 37   1962             Total Male Chinese   676500
# 38   1962           Total Female Chinese   656500
# 39   1962                  Total Indians   137100
# 40   1962             Total Male Indians    89000
# 41   1962           Total Female Indians    48100
# 42   1962    Other Ethnic Groups (Total)    29800
# 43   1962    Other Ethnic Groups (Males)    14700
# 44   1962  Other Ethnic Groups (Females)    15100
# 45   1963                Total Residents  1795000
# 46   1963           Total Male Residents   929300
# 47   1963         Total Female Residents   865700
# 48   1963                   Total Malays   257200
# 49   1963              Total Male Malays   132000
# 50   1963            Total Female Malays   125200
# 51   1963                  Total Chinese  1369300
# 52   1963             Total Male Chinese   694200
# 53   1963           Total Female Chinese   675100
# 54   1963                  Total Indians   137400
# 55   1963             Total Male Indians    87900
# 56   1963           Total Female Indians    49500
# 57   1963    Other Ethnic Groups (Total)    31100
# 58   1963    Other Ethnic Groups (Males)    15200
# 59   1963  Other Ethnic Groups (Females)    15900
# 60   1964                Total Residents  1841600
# 61   1964           Total Male Residents   951500
# 62   1964         Total Female Residents   890100
# 63   1964                   Total Malays   267000
# 64   1964              Total Male Malays   136700
# 65   1964            Total Female Malays   130300
# 66   1964                  Total Chinese  1405500
# 67   1964             Total Male Chinese   712300
# 68   1964           Total Female Chinese   693200
# 69   1964                  Total Indians   138400
# 70   1964             Total Male Indians    87400
# 71   1964           Total Female Indians    51000
# 72   1964    Other Ethnic Groups (Total)    30700
# 73   1964    Other Ethnic Groups (Males)    15100
# 74   1964  Other Ethnic Groups (Females)    15600
# 75   1965                Total Residents  1886900
# 76   1965           Total Male Residents   973800
# 77   1965         Total Female Residents   913100
# 78   1965                   Total Malays   277000
# 79   1965              Total Male Malays   141400
# 80   1965            Total Female Malays   135600
# 81   1965                  Total Chinese  1439500
# 82   1965             Total Male Chinese   729500
# 83   1965           Total Female Chinese   710000
# 84   1965                  Total Indians   140500
# 85   1965             Total Male Indians    88000
# 86   1965           Total Female Indians    52500
# 87   1965    Other Ethnic Groups (Total)    29900
# 88   1965    Other Ethnic Groups (Males)    14900
# 89   1965  Other Ethnic Groups (Females)    15000
# 90   1966                Total Residents  1934400
# 91   1966           Total Male Residents   995800
# 92   1966         Total Female Residents   938600
# 93   1966                   Total Malays   287700
# 94   1966              Total Male Malays   146500
# 95   1966            Total Female Malays   141200
# 96   1966                  Total Chinese  1473800
# 97   1966             Total Male Chinese   746700
# 98   1966           Total Female Chinese   727100
# 99   1966                  Total Indians   141200
# 100  1966             Total Male Indians    87200
# 101  1966           Total Female Indians    54000
# 102  1966    Other Ethnic Groups (Total)    31700
# 103  1966    Other Ethnic Groups (Males)    15400
# 104  1966  Other Ethnic Groups (Females)    16300
# 105  1967                Total Residents  1977600
# 106  1967           Total Male Residents  1017400
# 107  1967         Total Female Residents   960200
# 108  1967                   Total Malays   295800
# 109  1967              Total Male Malays   150400
# 110  1967            Total Female Malays   145400
# 111  1967                  Total Chinese  1504400
# 112  1967             Total Male Chinese   762100
# 113  1967           Total Female Chinese   742300
# 114  1967                  Total Indians   142900
# 115  1967             Total Male Indians    87500
# 116  1967           Total Female Indians    55400
# 117  1967    Other Ethnic Groups (Total)    34500
# 118  1967    Other Ethnic Groups (Males)    17400
# 119  1967  Other Ethnic Groups (Females)    17100
# 120  1968                Total Residents  2012000
# 121  1968           Total Male Residents  1034100
# 122  1968         Total Female Residents   977900
# 123  1968                   Total Malays   300500
# 124  1968              Total Male Malays   152600
# 125  1968            Total Female Malays   147900
# 126  1968                  Total Chinese  1531400
# 127  1968             Total Male Chinese   774700
# 128  1968           Total Female Chinese   756700
# 129  1968                  Total Indians   144600
# 130  1968             Total Male Indians    88200
# 131  1968           Total Female Indians    56400
# 132  1968    Other Ethnic Groups (Total)    35500
# 133  1968    Other Ethnic Groups (Males)    18600
# 134  1968  Other Ethnic Groups (Females)    16900
# 135  1969                Total Residents  2042500
# 136  1969           Total Male Residents  1046900
# 137  1969         Total Female Residents   995600
# 138  1969                   Total Malays   306000
# 139  1969              Total Male Malays   155600
# 140  1969            Total Female Malays   150400
# 141  1969                  Total Chinese  1555000
# 142  1969             Total Male Chinese   784900
# 143  1969           Total Female Chinese   770100
# 224  1974  Other Ethnic Groups (Females)    20800
# 225  1975                Total Residents  2262600
# 226  1975           Total Male Residents  1156100
# 227  1975         Total Female Residents  1106500
# 228  1975                   Total Malays   334100
# 229  1975              Total Male Malays   171800
# 230  1975            Total Female Malays   162300
# 231  1975                  Total Chinese  1733700
# 232  1975             Total Male Chinese   873500
# 233  1975           Total Female Chinese   860200
# 234  1975                  Total Indians   150200
# 235  1975             Total Male Indians    87700
# 236  1975           Total Female Indians    62500
# 237  1975    Other Ethnic Groups (Total)    44600
# 238  1975    Other Ethnic Groups (Males)    23100
# 239  1975  Other Ethnic Groups (Females)    21500
# 240  1976                Total Residents  2293300
# 241  1976           Total Male Residents  1171300
# 242  1976         Total Female Residents  1122000
# 243  1976                   Total Malays   337400
# 244  1976              Total Male Malays   173700
# 245  1976            Total Female Malays   163700
# 246  1976                  Total Chinese  1758800
# 247  1976             Total Male Chinese   886000
# 248  1976           Total Female Chinese   872800
# 249  1976                  Total Indians   151100
# 250  1976             Total Male Indians    87800
# 251  1976           Total Female Indians    63300
# 252  1976    Other Ethnic Groups (Total)    46000
# 253  1976    Other Ethnic Groups (Males)    23800
# 254  1976  Other Ethnic Groups (Females)    22200
# 255  1977                Total Residents  2325300
# 256  1977           Total Male Residents  1187300
# 257  1977         Total Female Residents  1138000
# 258  1977                   Total Malays   340700
# 259  1977              Total Male Malays   175600
# 260  1977            Total Female Malays   165100
# 261  1977                  Total Chinese  1785300
# 262  1977             Total Male Chinese   899300
# 263  1977           Total Female Chinese   886000
# 264  1977                  Total Indians   151900
# 265  1977             Total Male Indians    87900
# 266  1977           Total Female Indians    64000
# 267  1977    Other Ethnic Groups (Total)    47400
# 268  1977    Other Ethnic Groups (Males)    24500
# 269  1977  Other Ethnic Groups (Females)    22900
# 270  1978                Total Residents  2353600
# 271  1978           Total Male Residents  1201400
# 272  1978         Total Female Residents  1152200
# 273  1978                   Total Malays   344100
# 274  1978              Total Male Malays   177600
# 275  1978            Total Female Malays   166500
# 276  1978                  Total Chinese  1808200
# 277  1978             Total Male Chinese   910700
# 278  1978           Total Female Chinese   897500
# 279  1978                  Total Indians   152700
# 280  1978             Total Male Indians    87900
# 281  1978           Total Female Indians    64800
# 282  1978    Other Ethnic Groups (Total)    48600
# 283  1978    Other Ethnic Groups (Males)    25200
# 284  1978  Other Ethnic Groups (Females)    23400
# 285  1979                Total Residents  2383500
# 286  1979           Total Male Residents  1216300
# 287  1979         Total Female Residents  1167200
# 288  1979                   Total Malays   347600
# 289  1979              Total Male Malays   179600
# 290  1979            Total Female Malays   168000
# 291  1979                  Total Chinese  1832400
# 292  1979             Total Male Chinese   922900
# 293  1979           Total Female Chinese   909500
# 294  1979                  Total Indians   153500
# 295  1979             Total Male Indians    87900
# 296  1979           Total Female Indians    65600
# 297  1979    Other Ethnic Groups (Total)    50000
# 298  1979    Other Ethnic Groups (Males)    25900
# 299  1979  Other Ethnic Groups (Females)    24100
# 300  1980                Total Residents  2282125
# 301  1980           Total Male Residents  1159011
# 302  1980         Total Female Residents  1123114
# 303  1980                   Total Malays   328718
# 863  2017           Total Female Chinese  1511968
# 864  2017                  Total Indians   358821
# 865  2017             Total Male Indians   183818
# 866  2017           Total Female Indians   175003
# 867  2017    Other Ethnic Groups (Total)   128013
# 868  2017    Other Ethnic Groups (Males)    59531
# 869  2017  Other Ethnic Groups (Females)    68482
# 870  2018                Total Residents  3994283
# 871  2018           Total Male Residents  1955838
# 872  2018         Total Female Residents  2038445
# 873  2018                   Total Malays   535824
# 874  2018              Total Male Malays   266486
# 875  2018            Total Female Malays   269338
# 876  2018                  Total Chinese  2969281
# 877  2018             Total Male Chinese  1445375
# 878  2018           Total Female Chinese  1523906
# 879  2018                  Total Indians   360528
# 880  2018             Total Male Indians   184496
# 881  2018           Total Female Indians   176032
# 882  2018    Other Ethnic Groups (Total)   128650
# 883  2018    Other Ethnic Groups (Males)    59481
# 884  2018  Other Ethnic Groups (Females)    69169

# %% [markdown]
# Take a look at the dataset. `Year` is one variable indicating a potential time-series analysis. Other `variables` are number of population based on gender and race.
#
# Do note that there are several unimportant variables such as `Total Residents`, `Total Male Residents`, `Total Malays`, so on and so forth. The reason behind removing them is because we can simply obtain these values from the remaining `Gender-Race` variables.
#
# Also check the size and data types of the dataframe.

# %%
raw.shape
# Out:
# (885, 3)

# %%
raw.dtypes
# Out:
# year        int64
# level_1    object
# value       int64
# dtype: object

# %% [markdown]
# ### Performing Data Re-structuring
#
# Our two objectives are:
# 1. Removing irrelevant variables from `level_1` column
# 2. Creating a list of values for every remaining variables from `level_1` column

# %%
removed_var = ['Total Residents','Total Male Residents','Total Female Residents','Total Malays','Total Chinese', \
              'Total Indians','Other Ethnic Groups (Total)']

raw_1 = raw[~raw.level_1.isin(removed_var)] #Use DataFrame slicing, '~' means NOT
raw_1 #always good to save the edited dataframe under different variable, provided dataframe does not take a lot of memory.
# Out:
#      year                        level_1    value
# 4    1960              Total Male Malays   121000
# 5    1960            Total Female Malays   111200
# 7    1960             Total Male Chinese   636000
# 8    1960           Total Female Chinese   615600
# 10   1960             Total Male Indians    88000
# 11   1960           Total Female Indians    45200
# 13   1960    Other Ethnic Groups (Males)    14600
# 14   1960  Other Ethnic Groups (Females)    14800
# 19   1961              Total Male Malays   125700
# 20   1961            Total Female Malays   116800
# 22   1961             Total Male Chinese   657600
# 23   1961           Total Female Chinese   637400
# 25   1961             Total Male Indians    88800
# 26   1961           Total Female Indians    46900
# 28   1961    Other Ethnic Groups (Males)    14400
# 29   1961  Other Ethnic Groups (Females)    14800
# 34   1962              Total Male Malays   129300
# 35   1962            Total Female Malays   121000
# 37   1962             Total Male Chinese   676500
# 38   1962           Total Female Chinese   656500
# 40   1962             Total Male Indians    89000
# 41   1962           Total Female Indians    48100
# 43   1962    Other Ethnic Groups (Males)    14700
# 44   1962  Other Ethnic Groups (Females)    15100
# 49   1963              Total Male Malays   132000
# 50   1963            Total Female Malays   125200
# 52   1963             Total Male Chinese   694200
# 53   1963           Total Female Chinese   675100
# 55   1963             Total Male Indians    87900
# 56   1963           Total Female Indians    49500
# 58   1963    Other Ethnic Groups (Males)    15200
# 59   1963  Other Ethnic Groups (Females)    15900
# 64   1964              Total Male Malays   136700
# 65   1964            Total Female Malays   130300
# 67   1964             Total Male Chinese   712300
# 68   1964           Total Female Chinese   693200
# 70   1964             Total Male Indians    87400
# 71   1964           Total Female Indians    51000
# 73   1964    Other Ethnic Groups (Males)    15100
# 74   1964  Other Ethnic Groups (Females)    15600
# 79   1965              Total Male Malays   141400
# 80   1965            Total Female Malays   135600
# 82   1965             Total Male Chinese   729500
# 83   1965           Total Female Chinese   710000
# 85   1965             Total Male Indians    88000
# 86   1965           Total Female Indians    52500
# 88   1965    Other Ethnic Groups (Males)    14900
# 89   1965  Other Ethnic Groups (Females)    15000
# 94   1966              Total Male Malays   146500
# 95   1966            Total Female Malays   141200
# 97   1966             Total Male Chinese   746700
# 98   1966           Total Female Chinese   727100
# 100  1966             Total Male Indians    87200
# 101  1966           Total Female Indians    54000
# 103  1966    Other Ethnic Groups (Males)    15400
# 104  1966  Other Ethnic Groups (Females)    16300
# 109  1967              Total Male Malays   150400
# 110  1967            Total Female Malays   145400
# 112  1967             Total Male Chinese   762100
# 113  1967           Total Female Chinese   742300
# 115  1967             Total Male Indians    87500
# 116  1967           Total Female Indians    55400
# 118  1967    Other Ethnic Groups (Males)    17400
# 119  1967  Other Ethnic Groups (Females)    17100
# 124  1968              Total Male Malays   152600
# 125  1968            Total Female Malays   147900
# 127  1968             Total Male Chinese   774700
# 128  1968           Total Female Chinese   756700
# 130  1968             Total Male Indians    88200
# 131  1968           Total Female Indians    56400
# 133  1968    Other Ethnic Groups (Males)    18600
# 134  1968  Other Ethnic Groups (Females)    16900
# 139  1969              Total Male Malays   155600
# 140  1969            Total Female Malays   150400
# 142  1969             Total Male Chinese   784900
# 143  1969           Total Female Chinese   770100
# 145  1969             Total Male Indians    87900
# 146  1969           Total Female Indians    57200
# 148  1969    Other Ethnic Groups (Males)    18500
# 149  1969  Other Ethnic Groups (Females)    17900
# 154  1970              Total Male Malays   151795
# 155  1970            Total Female Malays   146213
# 157  1970             Total Male Chinese   782175
# 158  1970           Total Female Chinese   769271
# 160  1970             Total Male Indians    85083
# 161  1970           Total Female Indians    55808
# 163  1970    Other Ethnic Groups (Males)    11756
# 164  1970  Other Ethnic Groups (Females)    11462
# 169  1971              Total Male Malays   161300
# 170  1971            Total Female Malays   155000
# 172  1971             Total Male Chinese   812100
# 173  1971           Total Female Chinese   799000
# 175  1971             Total Male Indians    87600
# 176  1971           Total Female Indians    58700
# 178  1971    Other Ethnic Groups (Males)    20200
# 179  1971  Other Ethnic Groups (Females)    19000
# 184  1972              Total Male Malays   164200
# 185  1972            Total Female Malays   157000
# 187  1972             Total Male Chinese   828400
# 188  1972           Total Female Chinese   815000
# 190  1972             Total Male Indians    87600
# 191  1972           Total Female Indians    59700
# 193  1972    Other Ethnic Groups (Males)    20900
# 194  1972  Other Ethnic Groups (Females)    19600
# 199  1973              Total Male Malays   167100
# 200  1973            Total Female Malays   159000
# 202  1973             Total Male Chinese   845100
# 203  1973           Total Female Chinese   831700
# 205  1973             Total Male Indians    87600
# 206  1973           Total Female Indians    60800
# 790  2012             Total Male Indians   180948
# 791  2012           Total Female Indians   170077
# 793  2012    Other Ethnic Groups (Males)    59914
# 794  2012  Other Ethnic Groups (Females)    65763
# 799  2013              Total Male Malays   255176
# 800  2013            Total Female Malays   257661
# 802  2013             Total Male Chinese  1395183
# 803  2013           Total Female Chinese  1458568
# 805  2013             Total Male Indians   180889
# 806  2013           Total Female Indians   170778
# 808  2013    Other Ethnic Groups (Males)    60256
# 809  2013  Other Ethnic Groups (Females)    66240
# 814  2014              Total Male Malays   257036
# 815  2014            Total Female Malays   259621
# 817  2014             Total Male Chinese  1403927
# 818  2014           Total Female Chinese  1470453
# 820  2014             Total Male Indians   181359
# 821  2014           Total Female Indians   171662
# 823  2014    Other Ethnic Groups (Males)    60088
# 824  2014  Other Ethnic Groups (Females)    66593
# 829  2015              Total Male Malays   259108
# 830  2015            Total Female Malays   261815
# 832  2015             Total Male Chinese  1415303
# 833  2015           Total Female Chinese  1484704
# 835  2015             Total Male Indians   182304
# 836  2015           Total Female Indians   172648
# 838  2015    Other Ethnic Groups (Males)    59913
# 839  2015  Other Ethnic Groups (Females)    66895
# 844  2016              Total Male Malays   261564
# 845  2016            Total Female Malays   264324
# 847  2016             Total Male Chinese  1425244
# 848  2016           Total Female Chinese  1497928
# 850  2016             Total Male Indians   182935
# 851  2016           Total Female Indians   173941
# 853  2016    Other Ethnic Groups (Males)    59783
# 854  2016  Other Ethnic Groups (Females)    67840
# 859  2017              Total Male Malays   263912
# 860  2017            Total Female Malays   266798
# 862  2017             Total Male Chinese  1436284
# 863  2017           Total Female Chinese  1511968
# 865  2017             Total Male Indians   183818
# 866  2017           Total Female Indians   175003
# 868  2017    Other Ethnic Groups (Males)    59531
# 869  2017  Other Ethnic Groups (Females)    68482
# 874  2018              Total Male Malays   266486
# 875  2018            Total Female Malays   269338
# 877  2018             Total Male Chinese  1445375
# 878  2018           Total Female Chinese  1523906
# 880  2018             Total Male Indians   184496
# 881  2018           Total Female Indians   176032
# 883  2018    Other Ethnic Groups (Males)    59481
# 884  2018  Other Ethnic Groups (Females)    69169

# %%
var_year = raw.year.unique()

new_list = []
for year in var_year:
    new_list.append([year] + list(raw_1[raw_1.year == year].value))

column_name = ['Year','M-Malay','F-Malay','M-Chinese','F-Chinese','M-Indians','F-Indians','M-Other','F-Other']

# %% [markdown]
# Our next objectives will be making a new dataframe from the lists above. Ref: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
df = pd.DataFrame(new_list,columns=column_name)
df.head()
# Out:
#    Year  M-Malay  F-Malay  M-Chinese  F-Chinese  M-Indians  F-Indians  \
# 0  1960   121000   111200     636000     615600      88000      45200
# 1  1961   125700   116800     657600     637400      88800      46900
# 2  1962   129300   121000     676500     656500      89000      48100
# 3  1963   132000   125200     694200     675100      87900      49500
# 4  1964   136700   130300     712300     693200      87400      51000
#
#    M-Other  F-Other
# 0    14600    14800
# 1    14400    14800
# 2    14700    15100
# 3    15200    15900
# 4    15100    15600

# %% [markdown]
# Set variable `Year` as index.

# %%
df.set_index('Year', inplace=True)

# %%
df.head()
# Out:
#       M-Malay  F-Malay  M-Chinese  F-Chinese  M-Indians  F-Indians  M-Other  \
# Year
# 1960   121000   111200     636000     615600      88000      45200    14600
# 1961   125700   116800     657600     637400      88800      46900    14400
# 1962   129300   121000     676500     656500      89000      48100    14700
# 1963   132000   125200     694200     675100      87900      49500    15200
# 1964   136700   130300     712300     693200      87400      51000    15100
#
#       F-Other
# Year
# 1960    14800
# 1961    14800
# 1962    15100
# 1963    15900
# 1964    15600

# %% [markdown]
# This restructured data frame is what the question wants. But, we can further restructure this dataframe by making columns `Gender`, `Ethnicity`, and `Population`.

# %% [markdown]
# Notice that the indexings were mixed up after we removed some of the rows earlier.

# %%
raw_2 = raw_1.copy()
raw_2.reset_index(drop=True,inplace=True)
raw_2[:10]
# Out:
#    year                        level_1   value
# 0  1960              Total Male Malays  121000
# 1  1960            Total Female Malays  111200
# 2  1960             Total Male Chinese  636000
# 3  1960           Total Female Chinese  615600
# 4  1960             Total Male Indians   88000
# 5  1960           Total Female Indians   45200
# 6  1960    Other Ethnic Groups (Males)   14600
# 7  1960  Other Ethnic Groups (Females)   14800
# 8  1961              Total Male Malays  125700
# 9  1961            Total Female Malays  116800

# %% [markdown]
# We need to create the two new columns `ethnic` and `gender`.

# %%
raw_2["ethnic"] = raw_2['level_1'].map(lambda x: "Others" if x.find("Other") != -1 else x.split()[2])
raw_2["gender"] = raw_2['level_1'].map(lambda x: "Male" if x.find("Male") != -1 else "Female")

raw_2[:10]
# Out:
#    year                        level_1   value   ethnic  gender
# 0  1960              Total Male Malays  121000   Malays    Male
# 1  1960            Total Female Malays  111200   Malays  Female
# 2  1960             Total Male Chinese  636000  Chinese    Male
# 3  1960           Total Female Chinese  615600  Chinese  Female
# 4  1960             Total Male Indians   88000  Indians    Male
# 5  1960           Total Female Indians   45200  Indians  Female
# 6  1960    Other Ethnic Groups (Males)   14600   Others    Male
# 7  1960  Other Ethnic Groups (Females)   14800   Others  Female
# 8  1961              Total Male Malays  125700   Malays    Male
# 9  1961            Total Female Malays  116800   Malays  Female

# %% [markdown]
# We then need to drop `level_1` and shift column `value` to the end.

# %%
#dropping column
raw_2.drop(['level_1'], axis=1,inplace=True)

#switching column position
col_list = list(raw_2)
col_list[3],col_list[1] = col_list[1],col_list[3]
raw_2 = raw_2.reindex(columns = col_list)
raw_2[:10]
# Out:
#    year  gender   ethnic   value
# 0  1960    Male   Malays  121000
# 1  1960  Female   Malays  111200
# 2  1960    Male  Chinese  636000
# 3  1960  Female  Chinese  615600
# 4  1960    Male  Indians   88000
# 5  1960  Female  Indians   45200
# 6  1960    Male   Others   14600
# 7  1960  Female   Others   14800
# 8  1961    Male   Malays  125700
# 9  1961  Female   Malays  116800

# %%
df_2 = raw_2.copy()
# df_2.set_index('year',inplace=True)

# %% [markdown]
# Data look much neater. To analyze this dataframe, we need to use **groupby** unlike the previous dataframe `df`.

# %% [markdown]
# # B. Data Analysis

# %% [markdown]
# ### 1. At what rate does singapore population is increasing?
#
# For this question we might need to plot the historical population trend using matplotlib or seaborn.

# %%
#Since the question asked for singapore total population, I was confused why Abhisek asked me to remove that variable.
# We are going to sum every columns back to get the total poopulation column

df["Total"] = 0 #Initialize this column with zeros

for column_name in df.columns[:-1]:
    df["Total"] = df["Total"] + df[column_name]

df.head()
# Out:
#       M-Malay  F-Malay  M-Chinese  F-Chinese  M-Indians  F-Indians  M-Other  \
# Year
# 1960   121000   111200     636000     615600      88000      45200    14600
# 1961   125700   116800     657600     637400      88800      46900    14400
# 1962   129300   121000     676500     656500      89000      48100    14700
# 1963   132000   125200     694200     675100      87900      49500    15200
# 1964   136700   130300     712300     693200      87400      51000    15100
#
#       F-Other    Total
# Year
# 1960    14800  1646400
# 1961    14800  1702400
# 1962    15100  1750200
# 1963    15900  1795000
# 1964    15600  1841600

# %% [markdown]
# Do note that the Matplotlib code below still not fully refined. For the purpose of basic visualization, we don't really emphasize on stylings of the graph. We can also use tableau for better visualization.

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.scatter(df.index,df["Total"])
ax.set_title('Singapore Population Growth')
ax.set_xlabel("Year")
ax.set_ylabel("Number of Population")
plt.show()

# #add gridlines
# from matplotlib.ticker import MultipleLocator

# ax.grid()
# spacing = 2 #every year
# minorLocator_1 = MultipleLocator(spacing)
# minorLocator_2 = MultipleLocator(250000)
# # Set minor tick locations.
# ax.xaxis.set_minor_locator(minorLocator_1)
# ax.yaxis.set_minor_locator(minorLocator_2)
# # Set grid to use minor tick locations. 
# ax.grid(which = 'minor')

# %% [markdown]
# #### Linear Regression using Scikit-Learn
#
# Scikit-Learn (`sklearn`) will be our de-facto Machine Learning library in Python.
# Import the `LinearRegression` model from `sklearn.linear_model`.

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
all_model = LinearRegression()
# Train the Linear Regression model
all_model.fit(np.array(df.index).reshape((-1,1)), df["Total"]) #note that reshaping of index array is necessary

# Coefficients of the Linear Regression line
print('Intercept \t: b = ', all_model.intercept_)
print('Coefficients \t: a = ', all_model.coef_)
# Out:
# Intercept 	: b =  -79150662.53483345
# Coefficients 	: a =  [41200.21969608]

# %% [markdown]
# ##### Under linear growth assumption, Singapore's population is growing at a rate of 41.2k people per year.
#
# Now let's plot the trendline into the same plot we created above.

# %%
population_pred = all_model.predict(np.array(df.index).reshape((-1,1)))

# Plot the Predictions
f, ax = plt.subplots(1, 1, figsize=(8,6))
ax.annotate('+ 41,200 people/year',xy=(1970,3000000))
plt.scatter(df.index,df["Total"]) 
ax.plot(df.index, population_pred, color = "red")
ax.set_title('Singapore Population Growth')
ax.set_xlabel("Year")
ax.set_ylabel("Number of Population")

plt.show()

# %% [markdown]
# ### 2. Which Ethnic Group has the highest representation in Singapore?
#
# Sum all the population from each ethnic group.

# %%
df.loc[df.index].sum()[:-1].sort_values(ascending=False)
# Out:
# F-Chinese    63112372
# M-Chinese    62671373
# M-Malay      11702782
# F-Malay      11446983
# M-Indians     6970639
# F-Indians     5866098
# F-Other       1668893
# M-Other       1558752
# dtype: int64

# %% [markdown]
# Without even adding the number of male and female from each ethnic groups, we can simply say that the number of population based on ethnic groups is in the following order: `Chinese` > `Malays` > `Indians` > `Others`

# %% [markdown]
# ### 3. In the last 10 years which ethnic group has shown highest increment in population?
#
# Let's use both dataframe `df` and `df_2` to calculate the difference of population in 2009 and 2018 (10 year) for each ethnic groups.

# %%
#Using df
sub_list = []
for x,y in zip(list(df.loc[2018])[:-1],list(df.loc[2009])[:-1]):  #exclude the total column
    sub_list.append(x-y)
    
#We need to add male and female for each ethnic groups
final_list = []
for count in range(0,len(sub_list),2):
    final_list.append(sub_list[count]+sub_list[count+1])
    
print(sub_list)
print(final_list)
# Out:
# [17371, 18402, 85151, 113827, 6367, 10652, 2217, 6420]
# [35773, 198978, 17019, 8637]

# %%
final_list
# Out:
# [35773, 198978, 17019, 8637]

# %%
temp = pd.DataFrame([final_list], columns = ['Malays','Chinese','Indians','Other'])
temp
# Out:
#    Malays  Chinese  Indians  Other
# 0   35773   198978    17019   8637

# %% [markdown]
# Chinese ethnic group shown the highest increment in population in the last 10 years.

# %%
#Using df_2
temp = df_2.groupby(['year','ethnic'])['value'].agg('sum')

sub_list = []
for x,y in zip(list(temp.loc[2018]),list(temp.loc[2009])):  #exclude the total column
    sub_list.append(x-y)
    
#NOTE we don't need to add male and female since we have performed groupby earlier

temp = pd.DataFrame([sub_list], columns = ['Chinese','Malays','Indians','Other'])
temp
# Out:
#    Chinese  Malays  Indians  Other
# 0   198978   17019    35773   8637

# %%
#Reminder sample shopee assessment.
# temp = df_2.groupby(['year'])['value'].agg('sum')
# temp = pd.DataFrame(temp)
# temp.reset_index(inplace=True)
# temp['year'].iloc[temp.value.argmax()]

# %% [markdown]
# We actually get similar results with the one we did before.

# %% [markdown]
# ### 4. In which years female population was higher than male population?
#
# For this case we will use `df_2` and **groupby** for easier analysis.

# %%
temp = df_2.groupby(['year','gender'])['value'].agg('sum')
temp[:10]
# Out:
# year  gender
# 1960  Female    786800
#       Male      859600
# 1961  Female    815900
#       Male      886500
# 1962  Female    840700
#       Male      909500
# 1963  Female    865700
#       Male      929300
# 1964  Female    890100
#       Male      951500
# Name: value, dtype: int64

# %%
year_list = []
for year in range(1960,2019):
    if temp.loc[year,'Female'] > temp.loc[year,'Male']:
        year_list.append(year)
print(year_list)
print("count =",len(year_list))
# Out:
# [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# count = 20

# %% [markdown]
# It seems that female population started to lead from 1999 onwards.

# %%
temp.loc[year_list][:6]
# Out:
# year  gender
# 1999  Female    1614878
#       Male      1614805
# 2000  Female    1638696
#       Male      1634667
# 2001  Female    1667344
#       Male      1658558
# Name: value, dtype: int64

# %% [markdown]
# ### 5. What is the trend of past 10 years in male and female population?

# %%
temp = df_2.groupby(['year','gender'])['value'].agg('sum')
temp = pd.DataFrame(temp)
temp.reset_index(inplace=True)
# temp = temp[temp.year>2008]

year_list = temp.year.unique()
y_female = list(temp[temp.gender=="Female"]["value"])
y_male = list(temp[temp.gender=="Male"]["value"])

# %% [markdown]
# We need to make a line chart consisting of both `male` and `female` trends against `year`.

# %%
f, ax = plt.subplots(1, 1, figsize=(8,6))
ax.plot(year_list,y_female,color="red") 
ax.plot(year_list, y_male, color ="blue")
ax.set_title('Singapore Population Growth')
ax.set_xlabel("Year")
ax.set_ylabel("Number of Population")
# Out:
# Text(0, 0.5, 'Number of Population')

# %% [markdown]
# ### 6. What is the trend of China and India population?

# %%
temp = df_2.groupby(['year','ethnic'])['value'].agg('sum')
temp = pd.DataFrame(temp)
temp.reset_index(inplace=True)

year_list = temp.year.unique()
y_china = list(temp[temp.ethnic=="Chinese"]["value"])
y_india = list(temp[temp.ethnic=="Indians"]["value"])

# %%
f, ax = plt.subplots(1, 1, figsize=(8,6))
ax.plot(year_list,y_china,color="red") 
ax.plot(year_list, y_india, color ="green")
ax.set_title('Singapore Population Growth')
ax.set_xlabel("Year")
ax.set_ylabel("Number of Population")
# Out:
# Text(0, 0.5, 'Number of Population')

# %% [markdown]
# ### 7. What is the average increase in Chinese population?
#
# This question is similar to our first question. Yet we need to obtain the sum of population for both Male and Female Chinese.

# %%
#Aggregating dataframe on year and ethnic

temp = df_2.groupby(['year','ethnic'])['value'].agg('sum')
temp = pd.DataFrame(temp)
temp.reset_index(inplace=True)
temp = temp[temp.ethnic == "Chinese"]
temp.head()
# Out:
#     year   ethnic    value
# 0   1960  Chinese  1251600
# 4   1961  Chinese  1295000
# 8   1962  Chinese  1333000
# 12  1963  Chinese  1369300
# 16  1964  Chinese  1405500

# %%
# We perform linear regression again
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
c_model = LinearRegression()
# Train the Linear Regression model
c_model.fit(np.array(temp.year).reshape((-1,1)), temp.value) #need to reshape index for x array because of having only one variable a.k.a 1D array

# Coefficients of the Linear Regression line
print('Intercept \t: b = ', c_model.intercept_)
print('Coefficients \t: a = ', c_model.coef_)
# Out:
# Intercept 	: b =  -57747489.52285214
# Coefficients 	: a =  [30105.28778492]

# %% [markdown]
# The Chinese population is growing at an average rate of 30.1k people/year.

# %% [markdown]
# ### 8. What will be the rate for India?

# %%
#Aggregating dataframe on year and ethnic

temp = df_2.groupby(['year','ethnic'])['value'].agg('sum')
temp = pd.DataFrame(temp)
temp.reset_index(inplace=True)
temp = temp[temp.ethnic == "Indians"]
temp.head()
# Out:
#     year   ethnic   value
# 1   1960  Indians  133200
# 5   1961  Indians  135700
# 9   1962  Indians  137100
# 13  1963  Indians  137400
# 17  1964  Indians  138400

# %%
# We perform linear regression again
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
i_model = LinearRegression()
# Train the Linear Regression model
i_model.fit(np.array(temp.year).reshape((-1,1)), temp.value) #need to reshape index for x array because of having only one variable a.k.a 1D array

# Coefficients of the Linear Regression line
print('Intercept \t: b = ', i_model.intercept_)
print('Coefficients \t: a = ', i_model.coef_)
# Out:
# Intercept 	: b =  -8575273.257568674
# Coefficients 	: a =  [4420.73658679]

# %% [markdown]
# Rate of Indians = 4420 people/year. The Chinese population grew up to 7x faster than Indians

# %% [markdown]
# ### 9. What will be the population of Singapore in 2019?
# We simply do a linear regression since the growth resembles a linear growth. Since we have created a `all_model` previously, we are just going to use that.

# %%
round(all_model.predict(np.array(2019).reshape(-1,1))[0])
# Out:
# 4032581

# %%
df.tail(1)
# Out:
#       M-Malay  F-Malay  M-Chinese  F-Chinese  M-Indians  F-Indians  M-Other  \
# Year
# 2018   266486   269338    1445375    1523906     184496     176032    59481
#
#       F-Other    Total
# Year
# 2018    69169  3994283

# %% [markdown]
# ### 10. What will be the Chinese population in SG in 2019?

# %%
round(c_model.predict(np.array(2019).reshape(-1,1))[0])
# Out:
# 3035087

# %% [markdown]
# ### 11. What will be the Indian population in SG in 2019?

# %%
round(i_model.predict(np.array(2019).reshape(-1,1))[0])
# Out:
# 350194

# %% [markdown]
# ### 12. What will be the Male population in SG in 2019?

# %%
#Aggregating dataframe on year and gender

temp = df_2.groupby(['year','gender'])['value'].agg('sum')
temp = pd.DataFrame(temp)
temp.reset_index(inplace=True)
temp = temp[temp.gender == "Male"]
temp.head()
# Out:
#    year gender   value
# 1  1960   Male  859600
# 3  1961   Male  886500
# 5  1962   Male  909500
# 7  1963   Male  929300
# 9  1964   Male  951500

# %%
# We perform linear regression again
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
male_model = LinearRegression()
# Train the Linear Regression model
male_model.fit(np.array(temp.year).reshape((-1,1)), temp.value) #need to reshape index for x array because of having only one variable a.k.a 1D array

# Coefficients of the Linear Regression line
print('Coefficients \t: a = ', male_model.coef_)
# Out:
# Coefficients 	: a =  [19356.03927528]

# %%
round(male_model.predict(np.array(2019).reshape(-1,1))[0])
# Out:
# 1985826

# %%
temp.tail()
# Out:
#      year gender    value
# 109  2014   Male  1902410
# 111  2015   Male  1916628
# 113  2016   Male  1929526
# 115  2017   Male  1943545
# 117  2018   Male  1955838

# %% [markdown]
# Male population will increase from 1.955 mil to 1.985 mil based on the linear model. Note that the difference is greater than the gradient a which equals to 19.3k per year simply because the model is an approximation.

# %% [markdown]
# ### 13. What will be the Female population in SG in 2019?

# %%
#Aggregating dataframe on year and gender
temp = df_2.groupby(['year','gender'])['value'].agg('sum')
temp = pd.DataFrame(temp)
temp.reset_index(inplace=True)
temp = temp[temp.gender == "Female"]

female_model = LinearRegression()
# Train the Linear Regression model
female_model.fit(np.array(temp.year).reshape((-1,1)), temp.value) #need to reshape index for x array because of having only one variable a.k.a 1D array

print("The estimated female population in 2019 will be",round(female_model.predict(np.array(2019).reshape(-1,1))[0]))
# Out:
# The estimated female population in 2019 will be 2046755

# %% [markdown]
# ### 14. When will Singapore population reach 5 million?
# Take note that the dataset used does not represent the true Singapore population numbers.

# %% [markdown]
# To solve this we need to get the population equation. Basic form of linear eq: y = mx + c, where y is the `population number`, m is `coefficient`, x is the `year`, and c is the `intercept`.
#
# So now solve for x! x = (y-c)/m

# %%
# Coefficients of the Linear Regression line
print('Intercept \t: b = ', all_model.intercept_)
print('Coefficients \t: a = ', all_model.coef_[0])
# Out:
# Intercept 	: b =  -79150662.53483345
# Coefficients 	: a =  41200.21969608417

# %%
x = (5000000 - all_model.intercept_) / all_model.coef_[0]
m = (x-round(x))*12

print(f'The Singapore population will reach 5 mil in {round(x)} Month {round(m)}')
# Out:
# The Singapore population will reach 5 mil in 2042 Month 6

# %% [markdown]
# ### The End
